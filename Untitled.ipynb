# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sig_treshold = 0.0002

# %%
df=pd.read_pickle("dummy.pkl")
new_df=np.log(df)

# %%
df
# Out:
#                  hypertension  heart problem  cerebrovascular disease  \
# lv_height        9.299174e-93       0.292512                 0.202208
# lv_width         7.888306e-36       0.001685                 0.555571
# RV_angle         1.310208e-73       0.359707                 0.863412
# RV_height_ED     2.821807e-26       0.001314                 0.727354
# RV_hw_ratio_ED   1.192446e-02       0.023538                 0.406555
# RV_width_ED      5.164792e-52       0.180306                 0.161681
# hw_ratio_ED      4.444326e-13       0.040420                 0.847628
# mitral_distance  9.965602e-05       0.290081                 0.241023
# lv_angle         1.284351e-08       0.043134                 0.201808
# max_chin_ED      1.387074e-12       0.344340                 0.751775
# max_chin_ES      2.145673e-05       0.220956                 0.958165
# max_comp         1.343567e-07       0.171227                 0.584935
# median_chin_ED   5.858380e-30       0.875284                 0.929498
# median_chin_ES   4.182840e-12       0.301612                 0.387891
# median_comp      6.387393e-03       0.087812                 0.457948
# slice5_chin_ED   6.170102e-10       0.981586                 0.666947
# slice5_chin_ES   2.177809e-08       0.763489                 0.834967
# slice5_comp      2.387969e-02       0.776792                 0.514494
#
#                  peripheral vasccular disease  high cholesterol      diabetes  \
# lv_height                            0.052900          0.000178  2.884256e-09
# lv_width                             0.356557          0.011026  3.115467e-11
# RV_angle                             0.030279          0.956946  1.990114e-05
# RV_height_ED                         0.442456          0.935194  1.931732e-07
# RV_hw_ratio_ED                       0.937524          0.011215  8.858531e-01
# RV_width_ED                          0.307589          0.001596  2.569162e-11
# hw_ratio_ED                          0.373907          0.533575  4.582737e-01
# mitral_distance                      0.965677          0.288840  7.288879e-01
# lv_angle                             0.107146          0.010422  1.597419e-01
# max_chin_ED                          0.462354          0.010290  6.664142e-01
# max_chin_ES                          0.514902          0.084029  3.281597e-01
# max_comp                             0.152276          0.008673  5.128716e-02
# median_chin_ED                       0.965026          0.014159  2.015105e-01
# median_chin_ES                       0.316656          0.373108  2.109098e-01
# median_comp                          0.799651          0.312965  8.788722e-01
# slice5_chin_ED                       0.733708          0.006296  6.812282e-02
# slice5_chin_ES                       0.867019          0.689089  2.839176e-01
# slice5_comp                          0.726086          0.703307  8.919092e-01
#
#                    stroke    asthma      copd  bronchitis  parkinsons disease  \
# lv_height        0.060269  0.547468  0.525894    0.520787            0.826561
# lv_width         0.491521  0.122318  0.470027    0.261944            0.446900
# RV_angle         0.126021  0.249580  0.532682    0.230453            0.351304
# RV_height_ED     0.123742  0.007154  0.272779    0.225807            0.805288
# RV_hw_ratio_ED   0.001230  0.000142  0.058040    0.284524            0.838195
# RV_width_ED      0.018149  0.319568  0.491889    0.668398            0.485836
# hw_ratio_ED      0.047790  0.123356  0.659454    0.952905            0.401186
# mitral_distance  0.803962  0.931127  0.805296    0.396464            0.494391
# lv_angle         0.844985  0.073104  0.307565    0.330662            0.116289
# max_chin_ED      0.926032  0.324049  0.545749    0.140309            0.736268
# max_chin_ES      0.701696  0.033083  0.796393    0.055856            0.502660
# max_comp         0.106927  0.284940  0.569956    0.161741            0.938653
# median_chin_ED   0.295506  0.052429  0.705309    0.053772            0.364132
# median_chin_ES   0.710165  0.519374  0.551335    0.276527            0.647499
# median_comp      0.975293  0.909694  0.796596    0.697010            0.858513
# slice5_chin_ED   0.673402  0.147510  0.184321    0.175794            0.594561
# slice5_chin_ES   0.835964  0.103742  0.227544    0.209680            0.691021
# slice5_comp      0.411442  0.696999  0.353297    0.507770            0.446949
#
#                  depression
# lv_height          0.914925
# lv_width           0.839425
# RV_angle           0.082781
# RV_height_ED       0.021180
# RV_hw_ratio_ED     0.673035
# RV_width_ED        0.212884
# hw_ratio_ED        0.665057
# mitral_distance    0.291736
# lv_angle           0.868228
# max_chin_ED        0.526270
# max_chin_ES        0.539956
# max_comp           0.804179
# median_chin_ED     0.233464
# median_chin_ES     0.556455
# median_comp        0.528505
# slice5_chin_ED     0.516360
# slice5_chin_ES     0.971304
# slice5_comp        0.318525

# %%
sn.heatmap(new_df, annot=False)
plt.show()

# %%
0.05/(18*12)
# Out:
# 0.0002314814814814815

# %%
df[(df>0.0002)]= 0

# %%
df[(df!=0)]= 1
