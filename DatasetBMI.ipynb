# %%
import pandas as pd
import os

# %%
pd.read_csv("ukb45494.csv")
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7,12,39,40,42,43,44,45,46,198,200,220,222,224,226,228,230,232,234,236,366,367,2409,2412,2422,2425,2435,2438,2448,2451,2461,2464,2474,2477,2487,2490,2500,2503,2513,2516,2525,2526,2528,2529,2539,2542,2551,2552,2554,2555,2565,2568,2578,2581,2591,2594,2604,2607,2617,2620,2629,2630,2632,2633,2643,2646,2656,2659,2669,2672,2682,2685,2695,2698,2707,2708,2710,2711,2721,2724,2734,2737,2747,2750,2759,2760,2762,2763,2772,2773,2775,2776,2785,2786,2788,2789,2798,2799,2801,2802,2813,2820,2827,2828,2835,2836,3050,3258) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             eid  31-0.0  34-0.0  52-0.0      53-0.0 53-1.0      53-2.0 53-3.0  \
# 0       1000012     0.0  1949.0     2.0  2008-09-15    NaN  2016-11-03    NaN
# 1       1000029     1.0  1947.0     1.0  2008-08-12    NaN         NaN    NaN
# ...

# %%
my_list = _

# %%
cnt=0

# %%
for i in list(my_list['22427-2.0']):
    if (i==i):
        cnt+=1

# %%
data_list = os.listdir("data")

# %%
data_list
# Out:
# ['1000012',
#  '1000158',
#  '1000243',
#  '1000262',
#  '1000369',
#  '1000489',
#  '1000490',
#  '1000542',
#  '1000563',
#  '1000670',
#  '1000816',
#  '1001023',
#  '1001100',
#  '1001231',
#  '1001363',
#  '1001483',
#  '1001525',
#  '1001614',
#  '1001620',
#  '1001740',
#  '1001993',
#  '1002013',
#  '1002097',
#  '1002226',
#  '1002291',
#  '1002347',
#  '1002595',
#  '1002625',
#  '1003057',
#  '1003125',
#  '1003167',
#  '1003227',
#  '1003253',
#  '1003265',
#  '1003307',
#  '1003558',
#  '1003574',
#  '1003587',
#  '1003684',
#  '1003762',
#  '1003812',
#  '1004001',
#  '1004019',
#  '1004022',
#  '1004045',
#  '1004058',
#  '1004087',
#  '1004131',
#  '1004168',
#  '1004200',
#  '1004314',
#  '1004337',
#  '1004362',
#  '1004557',
#  '1004803',
#  '1004876',
#  '1004889',
#  '1004918',
#  '1004930',
#  '1004941',
#  '1005046',
#  '1005333',
#  '1005582',
#  '1005613',
#  '1005656',
#  '1005725',
#  '1005767',
#  '1005789',
#  '1005863',
#  '1005931',
#  '1005950',
# ...

# %%
cnt=0

# %%
for idx in data_list:
    try:
        idx = int(idx)
        bsa = my_list[ my_list['eid'] == idx]['22427-2.0'].item()
        if(bsa==bsa):
            cnt+=1
    except:
        print()

# %%
cnt
# Out:
# 39580

# %%
len(data_list)
# Out:
# 45739

# %%
my_list[ my_list['eid'] == 1000158]['22427-2.0'].item()
# Out:
# 2.05

# %%
my_list[ my_list['eid'] == 1000012]['22427-2.0']
# Out:
# 0    1.66
# Name: 22427-2.0, dtype: float64

# %%
for idx in data_list:
# Out:
#   File "<ipython-input-55-0216aa72fab9>", line 1
#     for idx in data_list:
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
cnt=0
for i in list(my_list['22427-2.0']):
    if(i==i):
        cnt+=1
print(cnt)
# Out:
#   File "<ipython-input-60-93b694de0b75>", line 3
#     if(i=i):
#         ^
# SyntaxError: invalid syntax

# %%
import nibabel as nib
a = set()
for f in data_list:
    try:
        nim = nib.load(f"data/{f}/la_4ch.nii.gz")
        image = nim.get_fdata()
        pixdim = nim.header['pixdim'][1:4]
        a.add(pixdim[0])
    except:
        print('munem')
# Out:
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem
# munem

# %%
a
