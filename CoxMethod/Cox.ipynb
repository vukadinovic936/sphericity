# %%
import pandas as pd
import numpy as np
import math
from datetime import date
from utils import *

# %%
prepare_for_cox("131338-0.0")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...

# %%
prepare_for_cox("131350-0.0")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...

# %%
prepare_for_cox("131354-0.0")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...

# %%
prepare_for_cox("131346-0.0")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...

# %%
prepare_for_cox("131286-0.0")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...

# %%
import pandas as pd
df = pd.read_csv("hw_ukb45494.csv")
# Out:
# C:\tools\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (14,41,42,46,47,48,368,369,2829,2830,2837,2838,3259) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df['5']

# %% [markdown]
# 131338-0.0 - Cardiomyopathy Date
#
#
# 131350-0.0 - Atrial fibrillation Date
#
#
# 131354-0.0 -  Heart Failure Date
#
#
# 131346-0.0 - Cardiac Arrest Date

# %%
df = df[df.days_without_incident != -1]

# %%
len(df)
# Out:
# 31421

# %%
df
# Out:
#            eid first_visit_date death_date   age  sex   BSA event_date  \
# 0      1000012       2008-09-15        NaN  59.0  0.0  1.66        NaN
# 1      1000158       2009-06-30        NaN  44.0  1.0  2.05        NaN
# 2      1000262       2010-06-22        NaN  58.0  0.0  1.89        NaN
# 3      1000369       2008-05-22        NaN  60.0  0.0  1.58        NaN
# 4      1000489       2009-06-27        NaN  66.0  1.0  1.73        NaN
# ...        ...              ...        ...   ...  ...   ...        ...
# 31710  6024225       2010-03-27        NaN  63.0  0.0  1.57        NaN
# 31711  6024290       2009-10-30        NaN  41.0  1.0  1.92        NaN
# 31712  6024323       2008-05-03        NaN  56.0  0.0  1.87        NaN
# 31713  6024624       2008-05-10        NaN  44.0  0.0  1.69        NaN
# 31715  6024797       2009-04-08        NaN  62.0  1.0  1.87        NaN
#
#              hw  CONST_DATE  days_without_incident
# 0      1.802815  2021-03-31                   4580
# ...
